# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ad = pd.read_csv("D:/108-1python/108-2期末專案/測試/123.csv",encoding='big5')
ad
# Out:
#           分析項分類             分析項    單位         每100克含量    名稱
# 0          一般成分              熱量  kcal              49  金冠蘋果
# 1          一般成分            修正熱量  kcal              46  金冠蘋果
# 2          一般成分              水分     g            86.3  金冠蘋果
# 3          一般成分             粗蛋白     g             0.4  金冠蘋果
# 4          一般成分             粗脂肪     g             0.1  金冠蘋果
# 5          一般成分          總碳水化合物     g              13  金冠蘋果
# 6          一般成分            膳食纖維     g             1.5  金冠蘋果
# 7           礦物質               鉀    mg             128  金冠蘋果
# 8           礦物質               鈣    mg               3  金冠蘋果
# 9           礦物質               鎂    mg               4  金冠蘋果
# 10          礦物質               鋅    mg             0.3  金冠蘋果
# 11          礦物質               磷    mg              11  金冠蘋果
# 12         維生素E          維生素E總量    mg            0.07  金冠蘋果
# 13         維生素E  α-維生素E當量(α-TE)    mg            0.06  金冠蘋果
# 14         維生素E           α-生育酚    mg            0.06  金冠蘋果
# ...

# %%
#只取前五行 https://blog.csdn.net/W_weiying/article/details/81411257
ad1 = ad.loc[:,['分析項分類','分析項','單位','每100克含量','名稱']]
#ad1.options.display.max_columns = None
ad1
# Out:
#           分析項分類             分析項    單位         每100克含量    名稱
# 0          一般成分              熱量  kcal              49  金冠蘋果
# 1          一般成分            修正熱量  kcal              46  金冠蘋果
# 2          一般成分              水分     g            86.3  金冠蘋果
# 3          一般成分             粗蛋白     g             0.4  金冠蘋果
# 4          一般成分             粗脂肪     g             0.1  金冠蘋果
# 5          一般成分          總碳水化合物     g              13  金冠蘋果
# 6          一般成分            膳食纖維     g             1.5  金冠蘋果
# 7           礦物質               鉀    mg             128  金冠蘋果
# 8           礦物質               鈣    mg               3  金冠蘋果
# 9           礦物質               鎂    mg               4  金冠蘋果
# 10          礦物質               鋅    mg             0.3  金冠蘋果
# 11          礦物質               磷    mg              11  金冠蘋果
# 12         維生素E          維生素E總量    mg            0.07  金冠蘋果
# 13         維生素E  α-維生素E當量(α-TE)    mg            0.06  金冠蘋果
# 14         維生素E           α-生育酚    mg            0.06  金冠蘋果
# ...

# %%
#https://leemeng.tw/practical-pandas-tutorial-for-aspiring-data-scientists.html#%E6%95%B8%E6%93%9A%E6%B8%85%E7%90%86-&-%E6%95%B4%E7%90%86_1
ad1.每100克含量 != "0"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 1351    True
# 1352    True
# 1353    True
# 1354    True
# 1355    True
# 1356    True
# 1357    True
# 1358    True
# 1359    True
# 1360    True
# 1361    True
# 1362    True
# 1363    True
# 1364    True
# 1365    True
# 1366    True
# 1367    True
# 1368    True
# 1369    True
# 1370    True
# 1371    True
# 1372    True
# 1373    True
# 1374    True
# 1375    True
# 1376    True
# 1377    True
# 1378    True
# 1379    True
# 1380    True
# Name: 每100克含量, Length: 1381, dtype: bool

# %%
#query 查詢 https://www.cnblogs.com/en-heng/p/5630849.html
ad1[ad1['名稱'] == '黃金小番茄'].head()
# Out:
#      分析項分類    分析項  單位 每100克含量        名稱
# 1314   一般成分      熱量  kcal          31  黃金小番茄
# 1315   一般成分  修正熱量  kcal          28  黃金小番茄
# 1316   一般成分      水分     g        91.5  黃金小番茄
# 1317   一般成分    粗蛋白     g         0.8  黃金小番茄
# 1318   一般成分    粗脂肪     g         0.2  黃金小番茄

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
msg = pi
while(msg != "bye"):
    msg = input('請輸入要查詢的蔬果名稱\n')
       
    if msg == "bye":
        print("感謝您的使用！")
        break
    
    print("以下是查詢結果")
    result = ad1[ad1['名稱'] == msg]
    # 设置列名与数据对齐 https://blog.csdn.net/wulei_1107103372/article/details/105258600
    pd.set_option('display.unicode.ambiguous_as_wide', True)
    pd.set_option('display.unicode.east_asian_width', True)

    print(result)
    print("欲結束查詢請輸入bye\n")
# Out:
# 請輸入要查詢的蔬果名稱
# 金冠蘋果
# 以下是查詢結果
#        分析項分類                 分析項  單位 每100克含量      名稱
# 0        一般成分                   熱量  kcal          49  金冠蘋果
# 1        一般成分               修正熱量  kcal          46  金冠蘋果
# 2        一般成分                   水分     g        86.3  金冠蘋果
# 3        一般成分                 粗蛋白     g         0.4  金冠蘋果
# 4        一般成分                 粗脂肪     g         0.1  金冠蘋果
# 5        一般成分           總碳水化合物     g          13  金冠蘋果
# 6        一般成分               膳食纖維     g         1.5  金冠蘋果
# 7          礦物質                     鉀    mg         128  金冠蘋果
# 8          礦物質                     鈣    mg           3  金冠蘋果
# 9          礦物質                     鎂    mg           4  金冠蘋果
# 10         礦物質                     鋅    mg         0.3  金冠蘋果
# 11         礦物質                     磷    mg          11  金冠蘋果
# 12        維生素E            維生素E總量    mg        0.07  金冠蘋果
# 13        維生素E  α-維生素E當量(α-TE)    mg        0.06  金冠蘋果
# 14        維生素E              α-生育酚    mg        0.06  金冠蘋果
# ...
