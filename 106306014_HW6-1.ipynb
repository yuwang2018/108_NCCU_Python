# %%
#Python continue 语句跳出本次循环，而break跳出整个循环。

#continue 语句用来告诉Python跳过当前循环的剩余语句，然后继续进行下一轮循环。

#continue语句用在while和for循环中。

# %% [markdown]
# ### 單字中英翻譯練習

# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
msg = input('請問你想練習英翻中還是中翻英呢？\n')
c = 0
w = 0

if ('英翻中' in msg):
    q1 = input('請輸入 read 的中文：\n')
    if ("閱讀" or "讀") in q1:
        print('答對囉！')
        c = c + 1
    else:
        print('答錯惹qq')
        w = w + 1
    q2 = input('請輸入 crown 的中文：\n')
    if ("皇冠" or "王冠") in q2:
        print('答對囉！')
        c = c + 1
    else:
        print('答錯惹qq')
        w = w + 1
    q3 = input('請輸入 toilet 的中文：\n')
    if ("廁所"or '洗手間') in q3:
        print('答對囉！')
        c = c + 1
    else:
        print('答錯惹qq')
        w = w + 1
    q4 = input('請輸入 bowl 的中文：\n')
    if "碗" in q4:
        print('答對囉！')
        c = c + 1
    else:
        print('答錯惹qq')
        w = w + 1
    q5 = input('請輸入 pants 的中文：\n')
    if ("長褲" or '褲子') in q5:
        print('答對囉！')
        c = c + 1
    else:
        print('答錯惹qq')
        w = w + 1
        print("你總共答對了{}題，答錯{}題\n".format(c,w))  
        print("以下是今天所有練習的單字：\n")
        mydict = {'read':"閱讀/讀",'crown':'皇冠/王冠','toilet':'廁所/洗手間','bowl':'碗','pants':'長褲/褲子'}
        for key in mydict:
            print('{}:{}'.format(key, mydict[key]))
            
else:
        c = 0
        w = 0
        q1 = input('請輸入 閱讀/讀 的英文：\n')
        if 'read' in q1:
            print('答對囉！')
            c = c + 1
        else:
            print('答錯惹qq')
            w = w + 1
        q2 = input('請輸入 皇冠/王冠 的中文：\n')
        if 'crown' in q2:
            print('答對囉！')
            c = c + 1
        else:
            print('答錯惹qq')
            w = w + 1
        q3 = input('請輸入 廁所/洗手間 的中文：\n')
        if 'toilet' in q3:
            print('答對囉！')
            c = c + 1
        else:
            print('答錯惹qq')
            w = w + 1
        q4 = input('請輸入 碗 的中文：\n')
        if "bowl" in q4:
            print('答對囉！')
            c = c + 1
        else:
            print('答錯惹qq')
            w = w + 1
        q5 = input('請輸入 長褲/褲子 的中文：\n')
        if 'pants' in q5:
            print('答對囉！')
            c = c + 1
        else:
            print('答錯惹qq')
            w = w + 1

        print("你總共答對了{}題，答錯{}題\n".format(c,w))  
        print("以下是今天所有練習的單字：\n")
        mydict = {'read':"閱讀/讀",'crown':'皇冠/王冠','toilet':'廁所/洗手間','bowl':'碗','pants':'長褲/褲子'}
        for key in mydict:
            print('{}:{}'.format(key, mydict[key]))
# Out:
# 請問你想練習英翻中還是中翻英呢？
# 中翻英
# 請輸入 閱讀/讀 的英文：
# read
# 答對囉！
# 請輸入 皇冠/王冠 的中文：
# clown
# 答錯惹qq
# 請輸入 廁所/洗手間 的中文：
# toilet
# 答對囉！
# 請輸入 碗 的中文：
# bow
# 答錯惹qq
# 請輸入 長褲/褲子 的中文：
# pants
# 答對囉！
# 你總共答對了3題，答錯2題
#
# 以下是今天所有練習的單字：
#
# read:閱讀/讀
# crown:皇冠/王冠
# toilet:廁所/洗手間
# bowl:碗
# pants:長褲/褲子
